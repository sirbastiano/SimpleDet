# %% [markdown]
# ## FLOPS

# %% [markdown]
# ### VFNet

# %%
# Specify the path to model config and checkpoint file
config_file = '/Data_large/marine/PythonProjects/MMDET/checkpoints/VENuS/Single/perfect_b10/18_BS_3_LR_0.0008_ME_30_OPT_SGD/vfnet_r18.py'

# !python3 flops.py  {config_file}
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 09/28 13:36:51 - mmengine - WARNING - Unsupported operator aten::max_pool2d encountered 1 time(s)
# 09/28 13:36:51 - mmengine - WARNING - Unsupported operator aten::add_ encountered 8 time(s)
# 09/28 13:36:51 - mmengine - WARNING - Unsupported operator aten::add encountered 7 time(s)
# 09/28 13:36:51 - mmengine - WARNING - Unsupported operator aten::mul encountered 60 time(s)
# 09/28 13:36:51 - mmengine - WARNING - Unsupported operator aten::exp encountered 10 time(s)
# 09/28 13:36:51 - mmengine - WARNING - Unsupported operator aten::div encountered 5 time(s)
# 09/28 13:36:51 - mmengine - WARNING - Unsupported operator aten::sub encountered 5 time(s)
# 09/28 13:36:51 - mmengine - WARNING - Unsupported operator prim::PythonOp.DeformConv2dFunction encountered 10 time(s)
# ...

# %% [markdown]
# ### RADCNet

# %%
# Specify the path to model config and checkpoint file
config_file = '/Data_large/marine/PythonProjects/MMDET/Deploy_out/Sentinel/Export/BS_2/LR_0.0005/IMG_2048/BANDS__b8/18_Optim_SGD/base_config.py'

# !python3 flops.py  {config_file}
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 09/28 13:44:38 - mmengine - WARNING - Unsupported operator aten::max_pool2d encountered 1 time(s)
# 09/28 13:44:38 - mmengine - WARNING - Unsupported operator aten::add_ encountered 8 time(s)
# 09/28 13:44:38 - mmengine - WARNING - Unsupported operator aten::add encountered 32 time(s)
# 09/28 13:44:38 - mmengine - WARNING - Unsupported operator aten::mul encountered 30 time(s)
# 09/28 13:44:38 - mmengine - WARNING - Unsupported operator aten::exp encountered 10 time(s)
# 09/28 13:44:38 - mmengine - WARNING - Unsupported operator aten::sigmoid encountered 10 time(s)
# ...

# %% [markdown]
# ## Latency

# %%
config_file = '/Data_large/marine/PythonProjects/MMDET/checkpoints/VENuS/Single/perfect_b10/18_BS_3_LR_0.0008_ME_30_OPT_SGD/vfnet_r18.py'
w = '/Data_large/marine/PythonProjects/MMDET/checkpoints/VENuS/Single/perfect_b10/18_BS_3_LR_0.0008_ME_30_OPT_SGD/epoch_30.pth'

# !python3 latency.py {config_file} --checkpoint {w} --task inference
# Out:
# 09/28 14:09:44 - mmengine - INFO - before build:
# 09/28 14:09:44 - mmengine - INFO - (GB) mem_used: 3.29 | uss: 0.48 | pss: 0.48 | total_proc: 1
# Loads checkpoint by local backend from path: /Data_large/marine/PythonProjects/MMDET/checkpoints/VENuS/Single/perfect_b10/18_BS_3_LR_0.0008_ME_30_OPT_SGD/epoch_30.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 09/28 14:09:45 - mmengine - INFO - after build:
# 09/28 14:09:46 - mmengine - INFO - (GB) mem_used: 4.56 | uss: 1.99 | pss: 2.00 | total_proc: 1
# /home/vessel/anaconda3/envs/openmmlab/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 09/28 14:09:57 - mmengine - INFO - ==================================
# ...

# %%
config_file = '/Data_large/marine/PythonProjects/MMDET/Deploy_out/VENuS/Export/BS_4/LR_0.0009/IMG_2048/BANDS__b10/18_Optim_SGD/base_config.py'
config_file_32 = '/Data_large/marine/PythonProjects/MMDET/checkpoints/VENuS/Export/BS_4/LR_0.0009/IMG_2048/BANDS__b10/18_Optim_SGD/base_config.py'

w = config_file.replace('base_config.py', 'epoch_30.pth')

# !python3 latency.py {config_file_32} --checkpoint {w} --task inference
# Out:
# 09/28 14:53:41 - mmengine - INFO - before build:
# 09/28 14:53:41 - mmengine - INFO - (GB) mem_used: 2.71 | uss: 0.52 | pss: 0.52 | total_proc: 1
# Loads checkpoint by local backend from path: /Data_large/marine/PythonProjects/MMDET/Deploy_out/VENuS/Export/BS_4/LR_0.0009/IMG_2048/BANDS__b10/18_Optim_SGD/epoch_30.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 09/28 14:53:43 - mmengine - INFO - after build:
# 09/28 14:53:43 - mmengine - INFO - (GB) mem_used: 4.00 | uss: 2.06 | pss: 2.06 | total_proc: 1
# /home/vessel/anaconda3/envs/openmmlab/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 09/28 14:53:54 - mmengine - INFO - ==================================
# ...
