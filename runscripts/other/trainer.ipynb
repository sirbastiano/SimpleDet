# %%
from Basetrainer import ObjectDetectionPipeline

# %%
seed = 54
pipeline = ObjectDetectionPipeline(batch_size=2, band=[5, 10], seed=seed, learning_rate=0.0015, max_epochs=30, sensor='VENUS')
pipeline.build() # Builds the pipeline

pipeline.train()
pipeline.test()
