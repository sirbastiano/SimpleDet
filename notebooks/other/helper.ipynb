# %%
import pandas as pd 
from pathlib import Path
import numpy as np 
import os, shutil
from utils import list_folder, remove_folder

# reading best folders to eliminate unnecessary checkpoints:
best_sen = pd.read_pickle('/Data_large/marine/PythonProjects/MMDET/test_results/global/best_folders_sentinel.pkl')
best_ven = pd.read_pickle('/Data_large/marine/PythonProjects/MMDET/test_results/global/best_folders.pkl')

# mode = 'Venus' # Sentinel

# # What to keep?
# toKeep = list(best_ven.values())
# toKeep = np.concatenate(toKeep).tolist()

# # List all folders:
# senFolders = list_folder(f'/Data_large/marine/PythonProjects/MMDET/checkpoints/{mode}_keep')
# all_subfolders = [list_folder(fold / 'norm_test_vfnet_r18') for fold in senFolders]
# all_subfolders = np.concatenate(all_subfolders).tolist()
# all_subfolders = [x.as_posix() for x in all_subfolders]

# ###### DELETION:
# list1 = all_subfolders
# list2 = toKeep

# # Find the intersection of the two lists
# intersection = list(set(list1) & set(list2))

# # Find the difference of each list from the intersection
# difference_list1 = list(set(list1) - set(intersection))
# difference_list2 = list(set(list2) - set(intersection))


# for element in difference_list1:
#     remove_folder(element)

# %%
best_ven[5]
# Out:
# ['/Data_large/marine/PythonProjects/MMDET/checkpoints/Venus_b5/norm_test_vfnet_r18/20240609_035232_LR_0.001_BATCH_4_IMG_2304',
#  '/Data_large/marine/PythonProjects/MMDET/checkpoints/Venus_b5/norm_test_vfnet_r18/20240607_201902_LR_0.001_BATCH_4_IMG_2304',
#  '/Data_large/marine/PythonProjects/MMDET/checkpoints/Venus_b5/norm_test_vfnet_r18/20240608_123423_LR_0.001_BATCH_4_IMG_2304']
