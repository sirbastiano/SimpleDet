# %%
import os 

os.listdir('/Data_large/marine/Datasets/VENuS/ds_L0/perfect')
# Out:
# ['ASH_L0_07703_20190115_MultiLayer_mask_OK.tif',
#  'ASH_L0_15562_20200710_MultiLayer_mask_OK.tif',
#  'ASH_L0_02686_20180203_MultiLayer_mask_OK.tif',
#  'ASH_L0_14315_20200415_MultiLayer_mask_OK.tif',
#  'ASH_L0_12140_20191117_MultiLayer_mask_OK.tif',
#  'ASH_L0_03962_20180502_MultiLayer_mask_OK.tif',
#  'ASH_L0_04542_20180611_MultiLayer_mask_OK.tif',
#  'ASH_L0_15968_20200807_MultiLayer_mask_OK.tif',
#  'ASH_L0_10197_20190706_MultiLayer_mask_OK.tif',
#  'ASH_L0_10951_20190827_MultiLayer_mask_OK.tif',
#  'ASH_L0_09385_20190511_MultiLayer_mask_OK.tif',
#  'ASH_L0_08805_20190401_MultiLayer_mask_OK.tif',
#  'ASH_L0_07993_20190204_MultiLayer_mask_OK.tif',
#  'ASH_L0_10806_20190817_MultiLayer_mask_OK.tif',
#  'ASH_L0_11995_20191107_MultiLayer_mask_OK.tif',
#  'ASH_L0_14895_20200525_MultiLayer_mask_OK.tif',
#  'ASH_L0_16693_20200926_MultiLayer_mask_OK.tif',
#  'ASH_L0_14779_20200517_MultiLayer_mask_OK.tif',
#  'ASH_L0_09124_20190423_MultiLayer_mask_OK.tif',
#  'ASH_L0_11096_20190906_MultiLayer_mask_OK.tif',
#  'ASH_L0_06775_20181112_MultiLayer_mask_OK.tif',
#  'ASH_L0_11937_20191103_MultiLayer_mask_OK.tif',
#  'ASH_L0_15475_20200704_MultiLayer_mask_OK.tif',
#  'ASH_L0_05557_20180820_MultiLayer_mask_OK.tif',
#  'ASH_L0_12604_20191219_MultiLayer_mask_OK.tif',
#  'ASH_L0_15156_20200612_MultiLayer_mask_OK.tif',
#  'ASH_L0_12401_20191205_MultiLayer_mask_OK.tif',
#  'ASH_L0_04745_20180625_MultiLayer_mask_OK.tif',
#  'ASH_L0_16432_20200908_MultiLayer_mask_OK.tif',
#  'ASH_L0_14518_20200429_MultiLayer_mask_OK.tif',
#  'ASH_L0_08602_20190318_MultiLayer_mask_OK.tif',
#  'ASH_L0_13416_20200213_MultiLayer_mask_OK.tif',
#  'ASH_L0_08109_20190212_MultiLayer_mask_OK.tif',
#  'ASH_L0_10632_20190805_MultiLayer_mask_OK.tif',
#  'ASH_L0_10458_20190724_MultiLayer_mask_OK.tif',
#  'ASH_L0_10429_20190722_MultiLayer_mask_OK.tif',
#  'ASH_L0_07964_20190202_MultiLayer_mask_OK.tif',
#  'ASH_L0_14663_20200509_MultiLayer_mask_OK.tif',
#  'ASH_L0_04629_20180617_MultiLayer_mask_OK.tif',
#  'ASH_L0_13474_20200217_MultiLayer_mask_OK.tif',
#  'ASH_L0_04397_20180601_MultiLayer_mask_OK.tif',
#  'ASH_L0_17041_20201020_MultiLayer_mask_OK.tif',
#  'ASH_L0_07819_20190123_MultiLayer_mask_OK.tif',
#  'ASH_L0_10023_20190624_MultiLayer_mask_OK.tif',
#  'ASH_L0_09269_20190503_MultiLayer_mask_OK.tif',
#  'ASH_L0_06717_20181108_MultiLayer_mask_OK.tif',
#  'ASH_L0_15707_20200720_MultiLayer_mask_OK.tif',
#  'ASH_L0_11908_20191101_MultiLayer_mask_OK.tif',
#  'ASH_L0_13822_20200312_MultiLayer_mask_OK.tif',
#  'ASH_L0_07877_20190127_MultiLayer_mask_OK.tif',
#  'ASH_L0_14837_20200521_MultiLayer_mask_OK.tif',
#  'ASH_L0_07645_20190111_MultiLayer_mask_OK.tif',
#  'ASH_L0_12343_20191201_MultiLayer_mask_OK.tif',
#  'ASH_L0_16519_20200914_MultiLayer_mask_OK.tif',
#  'ASH_L0_04658_20180619_MultiLayer_mask_OK.tif',
#  'ASH_L0_15649_20200716_MultiLayer_mask_OK.tif',
#  'ASH_L0_06398_20181017_MultiLayer_mask_OK.tif',
#  'ASH_L0_10922_20190825_MultiLayer_mask_OK.tif',
#  'ASH_L0_11792_20191024_MultiLayer_mask_OK.tif',
#  'ASH_L0_09878_20190614_MultiLayer_mask_OK.tif',
#  'ASH_L0_16316_20200831_MultiLayer_mask_OK.tif',
#  'ASH_L0_06311_20181011_MultiLayer_mask_OK.tif',
#  'ASH_L0_16461_20200910_MultiLayer_mask_OK.tif',
#  'ASH_L0_16490_20200912_MultiLayer_mask_OK.tif',
#  'ASH_L0_04136_20180514_MultiLayer_mask_OK.tif',
#  'ASH_L0_05789_20180905_MultiLayer_mask_OK.tif',
#  'ASH_L0_15069_20200606_MultiLayer_mask_OK.tif',
#  'ASH_L0_12227_20191123_MultiLayer_mask_OK.tif',
#  'ASH_L0_09182_20190427_MultiLayer_mask_OK.tif',
#  'ASH_L0_05818_20180907_MultiLayer_mask_OK.tif',
#  'ASH_L0_14547_20200501_MultiLayer_mask_OK.tif',
#  'ASH_L0_07761_20190119_MultiLayer_mask_OK.tif',
#  'ASH_L0_05325_20180804_MultiLayer_mask_OK.tif',
#  'ASH_L0_05528_20180818_MultiLayer_mask_OK.tif',
#  'ASH_L0_05383_20180808_MultiLayer_mask_OK.tif',
#  'ASH_L0_13706_20200304_MultiLayer_mask_OK.tif',
#  'ASH_L0_14199_20200407_MultiLayer_mask_OK.tif',
#  'ASH_L0_09733_20190604_MultiLayer_mask_OK.tif',
#  'ASH_L0_04948_20180709_MultiLayer_mask_OK.tif',
#  'ASH_L0_11966_20191105_MultiLayer_mask_OK.tif',
#  'ASH_L0_14692_20200511_MultiLayer_mask_OK.tif',
#  'ASH_L0_04890_20180705_MultiLayer_mask_OK.tif',
#  'ASH_L0_10284_20190712_MultiLayer_mask_OK.tif',
#  'ASH_L0_11589_20191010_MultiLayer_mask_OK.tif',
#  'ASH_L0_09443_20190515_MultiLayer_mask_OK.tif',
#  'ASH_L0_05412_20180810_MultiLayer_mask_OK.tif',
#  'ASH_L0_12024_20191109_MultiLayer_mask_OK.tif',
#  'ASH_L0_05673_20180828_MultiLayer_mask_OK.tif',
#  'ASH_L0_16548_20200916_MultiLayer_mask_OK.tif',
#  'ASH_L0_04281_20180524_MultiLayer_mask_OK.tif',
#  'ASH_L0_13387_20200211_MultiLayer_mask_OK.tif',
#  'ASH_L0_04687_20180621_MultiLayer_mask_OK.tif',
#  'ASH_L0_06572_20181029_MultiLayer_mask_OK.tif',
#  'ASH_L0_08254_20190222_MultiLayer_mask_OK.tif',
#  'ASH_L0_16258_20200827_MultiLayer_mask_OK.tif',
#  'ASH_L0_04774_20180627_MultiLayer_mask_OK.tif',
#  'ASH_L0_11386_20190926_MultiLayer_mask_OK.tif',
#  'ASH_L0_14228_20200409_MultiLayer_mask_OK.tif',
#  'ASH_L0_11734_20191020_MultiLayer_mask_OK.tif',
#  'ASH_L0_10371_20190718_MultiLayer_mask_OK.tif',
#  'ASH_L0_15359_20200626_MultiLayer_mask_OK.tif',
#  'ASH_L0_08138_20190214_MultiLayer_mask_OK.tif',
#  'ASH_L0_11299_20190920_MultiLayer_mask_OK.tif',
#  'ASH_L0_15910_20200803_MultiLayer_mask_OK.tif',
#  'ASH_L0_08921_20190409_MultiLayer_mask_OK.tif',
#  'ASH_L0_03817_20180422_MultiLayer_mask_OK.tif',
#  'ASH_L0_09559_20190523_MultiLayer_mask_OK.tif',
#  'ASH_L0_11531_20191006_MultiLayer_mask_OK.tif',
#  'ASH_L0_09588_20190525_MultiLayer_mask_OK.tif',
#  'ASH_L0_05006_20180713_MultiLayer_mask_OK.tif',
#  'ASH_L0_04484_20180607_MultiLayer_mask_OK.tif',
#  'ASH_L0_15939_20200805_MultiLayer_mask_OK.tif',
#  'ASH_L0_14170_20200405_MultiLayer_mask_OK.tif',
#  'ASH_L0_09356_20190509_MultiLayer_mask_OK.tif',
#  'ASH_L0_11618_20191012_MultiLayer_mask_OK.tif',
#  'ASH_L0_03788_20180420_MultiLayer_mask_OK.tif',
#  'ASH_L0_11212_20190914_MultiLayer_mask_OK.tif',
#  'ASH_L0_11560_20191008_MultiLayer_mask_OK.tif',
#  'ASH_L0_17012_20201018_MultiLayer_mask_OK.tif',
#  'ASH_L0_10226_20190708_MultiLayer_mask_OK.tif',
#  'ASH_L0_11038_20190902_MultiLayer_mask_OK.tif',
#  'ASH_L0_05093_20180719_MultiLayer_mask_OK.tif',
#  'ASH_L0_15330_20200624_MultiLayer_mask_OK.tif',
#  'ASH_L0_08979_20190413_MultiLayer_mask_OK.tif',
#  'ASH_L0_14953_20200529_MultiLayer_mask_OK.tif',
#  'ASH_L0_16403_20200906_MultiLayer_mask_OK.tif',
#  'ASH_L0_14025_20200326_MultiLayer_mask_OK.tif',
#  'ASH_L0_14054_20200328_MultiLayer_mask_OK.tif',
#  'ASH_L0_11067_20190904_MultiLayer_mask_OK.tif',
#  'ASH_L0_14286_20200413_MultiLayer_mask_OK.tif',
#  'ASH_L0_05354_20180806_MultiLayer_mask_OK.tif',
#  'ASH_L0_12633_20191221_MultiLayer_mask_OK.tif',
#  'ASH_L0_16954_20201014_MultiLayer_mask_OK.tif',
#  'ASH_L0_10980_20190829_MultiLayer_mask_OK.tif',
#  'ASH_L0_16606_20200920_MultiLayer_mask_OK.tif',
#  'ASH_L0_10139_20190702_MultiLayer_mask_OK.tif',
#  'ASH_L0_09501_20190519_MultiLayer_mask_OK.tif',
#  'ASH_L0_06340_20181013_MultiLayer_mask_OK.tif',
#  'ASH_L0_11415_20190928_MultiLayer_mask_OK.tif',
#  'ASH_L0_16896_20201010_MultiLayer_mask_OK.tif',
#  'ASH_L0_15678_20200718_MultiLayer_mask_OK.tif',
#  'ASH_L0_15214_20200616_MultiLayer_mask_OK.tif',
#  'ASH_L0_15881_20200801_MultiLayer_mask_OK.tif',
#  'ASH_L0_15533_20200708_MultiLayer_mask_OK.tif',
#  'ASH_L0_11183_20190912_MultiLayer_mask_OK.tif',
#  'ASH_L0_12778_20191231_MultiLayer_mask_OK.tif',
#  'ASH_L0_16867_20201008_MultiLayer_mask_OK.tif',
#  'ASH_L0_10893_20190823_MultiLayer_mask_OK.tif',
#  'ASH_L0_10255_20190710_MultiLayer_mask_OK.tif',
#  'ASH_L0_04194_20180518_MultiLayer_mask_OK.tif',
#  'ASH_L0_11763_20191022_MultiLayer_mask_OK.tif',
#  'ASH_L0_04223_20180520_MultiLayer_mask_OK.tif',
#  'ASH_L0_05267_20180731_MultiLayer_mask_OK.tif',
#  'ASH_L0_16142_20200819_MultiLayer_mask_OK.tif',
#  'ASH_L0_05586_20180822_MultiLayer_mask_OK.tif',
#  'ASH_L0_08834_20190403_MultiLayer_mask_OK.tif',
#  'ASH_L0_15852_20200730_MultiLayer_mask_OK.tif',
#  'ASH_L0_07558_20190105_MultiLayer_mask_OK.tif',
#  'ASH_L0_10342_20190716_MultiLayer_mask_OK.tif',
#  'ASH_L0_10081_20190628_MultiLayer_mask_OK.tif',
#  'ASH_L0_09414_20190513_MultiLayer_mask_OK.tif',
#  'ASH_L0_04803_20180629_MultiLayer_mask_OK.tif',
#  'ASH_L0_11241_20190916_MultiLayer_mask_OK.tif',
#  'ASH_L0_05905_20180913_MultiLayer_mask_OK.tif',
#  'ASH_L0_10748_20190813_MultiLayer_mask_OK.tif',
#  'ASH_L0_07674_20190113_MultiLayer_mask_OK.tif',
#  'ASH_L0_07732_20190117_MultiLayer_mask_OK.tif',
#  'ASH_L0_11473_20191002_MultiLayer_mask_OK.tif',
#  'ASH_L0_14750_20200515_MultiLayer_mask_OK.tif',
#  'ASH_L0_16751_20200930_MultiLayer_mask_OK.tif',
#  'ASH_L0_14431_20200423_MultiLayer_mask_OK.tif',
#  'ASH_L0_14576_20200503_MultiLayer_mask_OK.tif',
#  'ASH_L0_16664_20200924_MultiLayer_mask_OK.tif',
#  'ASH_L0_04919_20180707_MultiLayer_mask_OK.tif',
#  'ASH_L0_12169_20191119_MultiLayer_mask_OK.tif',
#  'ASH_L0_03846_20180424_MultiLayer_mask_OK.tif',
#  'ASH_L0_16229_20200825_MultiLayer_mask_OK.tif',
#  'ASH_L0_09704_20190602_MultiLayer_mask_OK.tif',
#  'ASH_L0_09849_20190612_MultiLayer_mask_OK.tif',
#  'ASH_L0_03730_20180416_MultiLayer_mask_OK.tif',
#  'ASH_L0_05441_20180812_MultiLayer_mask_OK.tif',
#  'ASH_L0_11647_20191014_MultiLayer_mask_OK.tif',
#  'ASH_L0_05731_20180901_MultiLayer_mask_OK.tif',
#  'ASH_L0_09994_20190622_MultiLayer_mask_OK.tif',
#  'ASH_L0_12285_20191127_MultiLayer_mask_OK.tif',
#  'ASH_L0_07500_20190101_MultiLayer_mask_OK.tif',
#  'ASH_L0_07239_20181214_MultiLayer_mask_OK.tif',
#  'ASH_L0_11357_20190924_MultiLayer_mask_OK.tif',
#  'ASH_L0_16635_20200922_MultiLayer_mask_OK.tif',
#  'ASH_L0_15040_20200604_MultiLayer_mask_OK.tif',
#  'ASH_L0_15185_20200614_MultiLayer_mask_OK.tif',
#  'ASH_L0_07181_20181210_MultiLayer_mask_OK.tif',
#  'ASH_L0_10777_20190815_MultiLayer_mask_OK.tif',
#  'ASH_L0_10864_20190821_MultiLayer_mask_OK.tif',
#  'ASH_L0_09820_20190610_MultiLayer_mask_OK.tif',
#  'ASH_L0_07790_20190121_MultiLayer_mask_OK.tif',
#  'ASH_L0_09066_20190419_MultiLayer_mask_OK.tif',
#  'ASH_L0_14141_20200403_MultiLayer_mask_OK.tif',
#  'ASH_L0_17070_20201022_MultiLayer_mask_OK.tif',
#  'ASH_L0_11705_20191018_MultiLayer_mask_OK.tif',
#  'ASH_L0_11154_20190910_MultiLayer_mask_OK.tif',
#  'ASH_L0_10110_20190630_MultiLayer_mask_OK.tif',
#  'ASH_L0_15736_20200722_MultiLayer_mask_OK.tif',
#  'ASH_L0_03759_20180418_MultiLayer_mask_OK.tif',
#  'ASH_L0_14982_20200531_MultiLayer_mask_OK.tif',
#  'ASH_L0_11328_20190922_MultiLayer_mask_OK.tif',
#  'ASH_L0_08428_20190306_MultiLayer_mask_OK.tif',
#  'ASH_L0_10574_20190801_MultiLayer_mask_OK.tif',
#  'ASH_L0_10603_20190803_MultiLayer_mask_OK.tif',
#  'ASH_L0_14373_20200419_MultiLayer_mask_OK.tif',
#  'ASH_L0_05238_20180729_MultiLayer_mask_OK.tif',
#  'ASH_L0_10835_20190819_MultiLayer_mask_OK.tif',
#  'ASH_L0_10313_20190714_MultiLayer_mask_OK.tif',
#  'ASH_L0_05499_20180816_MultiLayer_mask_OK.tif',
#  'ASH_L0_12749_20191229_MultiLayer_mask_OK.tif',
#  'ASH_L0_16780_20201002_MultiLayer_mask_OK.tif',
#  'ASH_L0_16287_20200829_MultiLayer_mask_OK.tif',
#  'ASH_L0_16200_20200823_MultiLayer_mask_OK.tif',
#  'ASH_L0_11676_20191016_MultiLayer_mask_OK.tif',
#  'ASH_L0_13996_20200324_MultiLayer_mask_OK.tif',
#  'ASH_L0_08747_20190328_MultiLayer_mask_OK.tif',
#  'ASH_L0_10168_20190704_MultiLayer_mask_OK.tif',
#  'ASH_L0_06630_20181102_MultiLayer_mask_OK.tif',
#  'ASH_L0_06543_20181027_MultiLayer_mask_OK.tif',
#  'ASH_L0_10400_20190720_MultiLayer_mask_OK.tif',
#  'ASH_L0_11125_20190908_MultiLayer_mask_OK.tif',
#  'ASH_L0_08283_20190224_MultiLayer_mask_OK.tif',
#  'ASH_L0_13764_20200308_MultiLayer_mask_OK.tif',
#  'ASH_L0_06891_20181120_MultiLayer_mask_OK.tif',
#  'ASH_L0_15098_20200608_MultiLayer_mask_OK.tif',
#  'ASH_L0_04716_20180623_MultiLayer_mask_OK.tif',
#  'ASH_L0_09965_20190620_MultiLayer_mask_OK.tif',
#  'ASH_L0_15127_20200610_MultiLayer_mask_OK.tif',
#  'ASH_L0_14083_20200330_MultiLayer_mask_OK.tif',
#  'ASH_L0_07529_20190103_MultiLayer_mask_OK.tif',
#  'ASH_L0_11270_20190918_MultiLayer_mask_OK.tif',
#  'ASH_L0_09907_20190616_MultiLayer_mask_OK.tif',
#  'ASH_L0_05180_20180725_MultiLayer_mask_OK.tif',
#  'ASH_L0_07848_20190125_MultiLayer_mask_OK.tif',
#  'ASH_L0_16113_20200817_MultiLayer_mask_OK.tif',
#  'ASH_L0_16374_20200904_MultiLayer_mask_OK.tif',
#  'ASH_L0_16925_20201012_MultiLayer_mask_OK.tif',
#  'ASH_L0_08863_20190405_MultiLayer_mask_OK.tif',
#  'ASH_L0_14924_20200527_MultiLayer_mask_OK.tif',
#  'ASH_L0_06601_20181031_MultiLayer_mask_OK.tif',
#  'ASH_L0_05702_20180830_MultiLayer_mask_OK.tif',
#  'ASH_L0_08718_20190326_MultiLayer_mask_OK.tif',
#  'ASH_L0_07413_20181226_MultiLayer_mask_OK.tif',
#  'ASH_L0_16055_20200813_MultiLayer_mask_OK.tif',
#  'ASH_L0_05209_20180727_MultiLayer_mask_OK.tif',
#  'ASH_L0_08515_20190312_MultiLayer_mask_OK.tif',
#  'ASH_L0_13445_20200215_MultiLayer_mask_OK.tif',
#  'ASH_L0_08950_20190411_MultiLayer_mask_OK.tif',
#  'ASH_L0_09936_20190618_MultiLayer_mask_OK.tif',
#  'ASH_L0_15997_20200809_MultiLayer_mask_OK.tif',
#  'ASH_L0_02628_20180130_MultiLayer_mask_OK.tif',
#  'ASH_L0_16171_20200821_MultiLayer_mask_OK.tif',
#  'ASH_L0_10719_20190811_MultiLayer_mask_OK.tif',
#  'ASH_L0_12430_20191207_MultiLayer_mask_OK.tif',
#  'ASH_L0_04977_20180711_MultiLayer_mask_OK.tif',
#  'ASH_L0_05847_20180909_MultiLayer_mask_OK.tif',
#  'ASH_L0_16084_20200815_MultiLayer_mask_OK.tif',
#  'ASH_L0_09153_20190425_MultiLayer_mask_OK.tif',
#  'ASH_L0_09472_20190517_MultiLayer_mask_OK.tif',
#  'ASH_L0_05470_20180814_MultiLayer_mask_OK.tif',
#  'ASH_L0_16722_20200928_MultiLayer_mask_OK.tif',
#  'ASH_L0_17099_20201024_MultiLayer_mask_OK.tif',
#  'ASH_L0_05035_20180715_MultiLayer_mask_OK.tif',
#  'ASH_L0_05151_20180723_MultiLayer_mask_OK.tif',
#  'ASH_L0_16838_20201006_MultiLayer_mask_OK.tif',
#  'ASH_L0_16577_20200918_MultiLayer_mask_OK.tif',
#  'ASH_L0_15388_20200628_MultiLayer_mask_OK.tif',
#  'ASH_L0_09211_20190429_MultiLayer_mask_OK.tif',
#  'ASH_L0_05876_20180911_MultiLayer_mask_OK.tif',
#  'ASH_L0_05615_20180824_MultiLayer_mask_OK.tif',
#  'ASH_L0_11444_20190930_MultiLayer_mask_OK.tif',
#  'ASH_L0_17128_20201026_MultiLayer_mask_OK.tif',
#  'ASH_L0_08892_20190407_MultiLayer_mask_OK.tif',
#  'ASH_L0_12662_20191223_MultiLayer_mask_OK.tif',
#  'ASH_L0_12865_20200106_MultiLayer_mask_OK.tif',
#  'ASH_L0_09675_20190531_MultiLayer_mask_OK.tif',
#  'ASH_L0_07036_20181130_MultiLayer_mask_OK.tif']

# %%
import rasterio as rio 


def read_tif(path):
    with rio.open(path) as src:
        return src.read(10), src.profile
    
path = '/Data_large/marine/PythonProjects/MMDET/tgt_imgs/ASH_L0_09936_20190618_MultiLayer_mask_OK.tif'

img, profile = read_tif(path)

# write fuction to save_tif inot a tif. file new:
def save_tif(img, path, profile):
    with rio.open(path, 'w', **profile) as dst:
        dst.write(img, 10)
        
save_tif(img, '/Data_large/marine/PythonProjects/MMDET/tgt_imgs/SAV_ASH_L0_09936_20190618_MultiLayer_mask_OK.tif', profile)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_io.pyx:1488, in rasterio._io.DatasetWriterBase.__init__()
#
# File rasterio/_err.pyx:221, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Attempt to create new tiff file '/Data_large/marine/PythonProjects/MMDET/tgt_imgs/SAV_ASH_L0_09936_20190618_MultiLayer_mask_OK.tif' failed: Permission denied
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[1], line 17
#      14     with rio.open(path, 'w', **profile) as dst:
#      15         dst.write(img, 10)
# ---> 17 save_tif(img, '/Data_large/marine/PythonProjects/MMDET/tgt_imgs/SAV_ASH_L0_09936_20190618_MultiLayer_mask_OK.tif', profile)
#
# Cell In[1], line 14, in save_tif(img, path, profile)
#      13 def save_tif(img, path, profile):
# ---> 14     with rio.open(path, 'w', **profile) as dst:
#      15         dst.write(img, 10)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/rasterio/env.py:451, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     448     session = DummySession()
#     450 with env_ctor(session=session):
# --> 451     return f(*args, **kwds)
#
# File ~/anaconda3/envs/openmmlab/lib/python3.8/site-packages/rasterio/__init__.py:314, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     312 writer = get_writer_for_driver(driver)
#     313 if writer is not None:
# --> 314     dataset = writer(
#     315         path,
#     316         mode,
#     317         driver=driver,
#     318         width=width,
#     319         height=height,
#     320         count=count,
#     321         crs=crs,
#     322         transform=transform,
#     323         dtype=dtype,
#     324         nodata=nodata,
#     325         sharing=sharing,
#     326         **kwargs
#     327     )
#     328 else:
#     329     raise DriverCapabilityError(
#     330         "Writer does not exist for driver: %s" % str(driver)
#     331     )
#
# File rasterio/_io.pyx:1493, in rasterio._io.DatasetWriterBase.__init__()
#
# RasterioIOError: Attempt to create new tiff file '/Data_large/marine/PythonProjects/MMDET/tgt_imgs/SAV_ASH_L0_09936_20190618_MultiLayer_mask_OK.tif' failed: Permission denied
